# %% [markdown]
# ## Линейная модель
#
# Линейная модель - это математическая модель, используемая в машинном обучении для предсказания значений на основе линейной комбинации входных признаков. Она предполагает, что выходное значение (прогноз) можно выразить как взвешенную сумму входных признаков с добавлением смещения (bias). Математически это можно записать следующим образом:
#
#
# $\hat{y} = w_1x_1 + w_2x_2 + \ldots + w_nx_n + b$
#
# где:
# - $\hat{y}$ - прогнозируемое значение,
# - $w_1, w_2, \ldots, w_n$ - веса (параметры) модели для каждого признака,
# - $x_1, x_2, \ldots, x_n$ - входные признаки,
# - $b$ - смещение (bias).
#
# ### Вычисление выхода линейной модели
#
# Для вычисления выхода линейной модели, просто подставьте значения признаков в уравнение, используя соответствующие веса и смещение. Матричная формула для вычисления выхода линейной модели для набора данных \(X\) выглядит следующим образом:
#
# $\hat{Y} = X \cdot \mathbf{w} + b$
#
# где:
# - $\hat{Y}$ - вектор прогнозов для всего набора данных,
# - $X$ - матрица признаков, где каждая строка представляет один образец, а столбцы - признаки,
# - $\mathbf{w}$ - вектор весов модели,
# - $b$ - смещение (bias).
#
# ### Обучение линейной модели
#
# Обучение линейной модели заключается в настройке параметров (весов и смещения) так, чтобы они наилучшим образом соответствовали обучающим данным. Одним из наиболее распространенных методов обучения линейной модели является градиентный спуск.
#
# ### Градиентный спуск
#
# Градиентный спуск - это метод оптимизации, используемый для обновления параметров модели с целью минимизации функции потерь. Функция потерь оценивает, насколько хорошо модель предсказывает реальные значения на обучающих данных.
#
# Для линейной регрессии, часто используется среднеквадратичная ошибка (Mean Squared Error - MSE) в качестве функции потерь:
#
# $MSE = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2$
#
# где:
# - $N$ - количество обучающих примеров,
# - $y_i$ - реальное значение для i-го примера,
# - $\hat{y}_i$ - прогнозированное значение для i-го примера.
#
# ### Корректировка весов модели
#
# Для обновления весов модели в методе градиентного спуска, используется градиент функции потерь по отношению к параметрам модели. Градиент показывает направление наибольшего увеличения функции потерь, поэтому мы двигаемся в противоположном направлении градиента, чтобы уменьшить потери. Формула для обновления весов выглядит следующим образом:
#
# $\mathbf{w}_{\text{новые}} = \mathbf{w}_{\text{старые}} - \text{learning_rate} \cdot \nabla L$
#
# где:
# - $\mathbf{w}_{\text{новые}}$ - новые веса после обновления,
# - $\mathbf{w}_{\text{старые}}$ - текущие веса,
# - $\text{learning_rate}$ - скорость обучения (коэффициент, контролирующий размер шага градиентного спуска),
# - $\nabla L$ - градиент функции потерь по параметрам модели.
#
# Этот процесс повторяется до достижения сходимости или определенного числа итераций.
#
# ## Классификатор на линейной модели
#
# На линейной модели можно построить и классификатор. Для этого нужно выход линейной модели отбразить в интервал от 0 до 1. В этом нам поможет логистическая функция:
#
# $\sigma(z) = \frac{1}{1 + e^{-z}}$
#
# Для обучения скорректируем функцию потерь. Нетрудно показать, что функция, называемая кросс-энтропией на самом деле соответствует максимизации правдоподобия (кстати, почитайте про правдоподобие), ниже представлено выражение для нее
#
# $BCE = -\frac{1}{N} \sum_{i=1}^{N} \left(y_i \log(\hat{y}_i) + (1 - y_i) \log(1 - \hat{y}_i)\right)$
#
# где:
# - $N$ - количество обучающих примеров,
# - $y_i$ - истинная метка класса (0 или 1) для i-го примера,
# - $\hat{y}_i$ - вероятность принадлежности к классу 1 для i-го примера (выход сигмоидной функции).
#
# Будем считать, что модель относит объект к 1 классу, если ее выход $>=0.5$, иначе - 0 класс.
#
# ## Как считать градиенты
#
# Приведу градиент для кросс-энтропии:
#
# $\nabla_{\mathbf{w}} \text{BCE} = -\frac{1}{N} \mathbf{X}^T (\mathbf{y} - \hat{\mathbf{y}})$
#
# Для MSE вычислить градиент самостоятельно

# %%
import numpy as np
import matplotlib.pyplot as plt


class LinearModel:
    def __init__(self, num_features):
        self.num_features = num_features
        # Инициализация весов случайными значениями и смещения
        self.weights = np.random.randn(num_features)
        self.bias = np.random.randn()

    def __call__(self, X):
        # Вычисление линейной модели: y = Xw + b
        return np.dot(X, self.weights) + self.bias


class LinearRegressor(LinearModel):
    def fit(self, X, y, learning_rate=0.01, epochs=100):
        error_history = []
        for _ in range(epochs):
            predictions = self(X)  # предсказания
            error = y - predictions  # ошибка
            gradient = -2 * np.dot(X.T, error) / len(X)  # градиент
            self.weights -= learning_rate * gradient  # обновление весов
            self.bias -= learning_rate * np.mean(error)  # обновление смещения
            current_error = np.mean(error ** 2)  # MSE
            error_history.append(current_error)
        return error_history

    def predict(self, X):
        return self(X)


class LinearClassifier(LinearModel):
    def fit(self, X, y, learning_rate=0.01, epochs=100):
        error_history = []
        for _ in range(epochs):
            predictions = self(X)  # линейные предсказания
            sigmoid = 1 / (1 + np.exp(-predictions))  # сигмоида
            error = y - sigmoid  # ошибка
            gradient = -np.dot(X.T, error) / len(X)  # градиент
            self.weights -= learning_rate * gradient  # обновление весов
            self.bias -= learning_rate * np.mean(error)  # обновление смещения
            current_error = -np.mean(y * np.log(sigmoid) + (1 - y) * np.log(1 - sigmoid))  # кросс-энтропия
            error_history.append(current_error)
        return error_history

    def predict(self, X):
        predictions = self(X)
        sigmoid = 1 / (1 + np.exp(-predictions))
        return np.round(sigmoid)

    def predict_proba(self, X):
        predictions = self(X)
        sigmoid = 1 / (1 + np.exp(-predictions))
        return sigmoid

# %% [markdown]
# ## Проверьте модели на данных
#
# ### Линейная модель
#
# #### Description:
# The Student Performance Dataset is a dataset designed to examine the factors influencing academic student performance. The dataset consists of 10,000 student records, with each record containing information about various predictors and a performance index.
#
# #### Variables:
# - Hours Studied: The total number of hours spent studying by each student.
# - Previous Scores: The scores obtained by students in previous tests.
# - Extracurricular Activities: Whether the student participates in extracurricular activities (Yes or No).
# - Sleep Hours: The average number of hours of sleep the student had per day.
# - Sample Question Papers Practiced: The number of sample question papers the student practiced.
#
# #### Target Variable:
#
# - Performance Index: A measure of the overall performance of each student. The performance index represents the student's academic performance and has been rounded to the nearest integer. The index ranges from 10 to 100, with higher values indicating better performance.

# %%
import pandas as pd

# Пример загрузки данных из CSV файла
data = pd.read_csv('C:/Users/Tech/Downloads/student_performance.csv')  # Замените на путь к вашему файлу


print(data.head())  # Печать первых 5 строк данных
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
import pandas as pd

# قراءة البيانات من الملف
data = pd.read_csv('C:/Users/Tech/Downloads/Student_Performance.csv')

# عرض أول 5 أسطر من البيانات للتأكد من الشكل الصحيح
print(data.head())

# التحقق من القيم المفقودة في البيانات
print(data.isnull().sum())  # التحقق من القيم المفقودة في كل عمود

# تحديد الهدف (Y) والمتغيرات المستقلة (X)
Y = data['Performance Index']  # الهدف
X = data.drop('Performance Index', axis=1)  # جميع الأعمدة ما عدا الهدف

# التأكد من أن جميع القيم في 'Extracurricular Activities' هي 'Yes' أو 'No'
print(X['Extracurricular Activities'].unique())  # للتحقق من القيم الفريدة

# استبدال القيم في 'Extracurricular Activities' بـ 1 و 0
X['Extracurricular Activities'] = X['Extracurricular Activities'].replace({'Yes': 1, 'No': 0}).astype(int)

# تحويل X إلى مصفوفة numpy
X = X.to_numpy()

# عرض أول 5 صفوف من X للتحقق
print(X[:5])
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# ...

# %%
# Вычисляем среднее и стандартное отклонение по столбцам
mean = X.mean(axis=0)  # Среднее по каждому столбцу
std = X.std(axis=0)  # Стандартное отклонение по каждому столбцу

# Нормализуем данные по столбцам (стандартное масштабирование)
normalized_X = (X - mean) / std  # Стандартное масштабирование (Z-преобразование)

# Нормализуем выходные данные (можно использовать простое стандартное масштабирование)
normalized_Y = (Y - Y.mean()) / Y.std()  # Нормализация Y

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# قراءة البيانات من الملف
data = pd.read_csv('C:/Users/Tech/Downloads/Student_Performance.csv')  # تأكد من المسار الصحيح للملف

# عرض أول 5 أسطر من البيانات للتأكد من الشكل الصحيح
print(data.head())

# التحقق من القيم المفقودة في البيانات
print(data.isnull().sum())  # التحقق من القيم المفقودة في كل عمود

# تحديد الهدف (Y) والمتغيرات المستقلة (X)
Y = data['Performance Index']  # المتغير المستهدف (مؤشر الأداء)
X = data.drop('Performance Index', axis=1)  # المميزات (جميع الأعمدة باستثناء المتغير المستهدف)

# التأكد من أن جميع القيم في 'Extracurricular Activities' هي 'Yes' أو 'No'
print(X['Extracurricular Activities'].unique())  # للتحقق من القيم الفريدة

# استبدال القيم في 'Extracurricular Activities' بـ 1 و 0
X['Extracurricular Activities'] = X['Extracurricular Activities'].replace({'Yes': 1, 'No': 0}).astype(int)

# معالجة القيم المفقودة (NaN) بالإكمال بالمتوسط
X.fillna(X.mean(), inplace=True)
Y.fillna(Y.mean(), inplace=True)

# تحجيم البيانات باستخدام StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # تحجيم البيانات

# تقسيم البيانات إلى مجموعات تدريب واختبار
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# تعريف عدد المميزات
num_features = X_train.shape[1]  # عدد الأعمدة في X_train

# تعريف نموذج الانحدار الخطي (أو أي نموذج آخر تريد استخدامه)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# تدريب النموذج على بيانات التدريب
lr.fit(X_train, Y_train)

# التنبؤ بالقيم على بيانات الاختبار
Y_pred = lr.predict(X_test)

# عرض التنبؤات
print(f"التنبؤات: {Y_pred}")
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# ...

# %%
# تعريف المدخلات والنتائج
import numpy as np

# افترض أن لدينا 100 مثال مع 5 ميزات
X = np.random.randn(100, 5)  # 100 عينات و 5 ميزات
y = np.random.randn(100)  # 100 قيمة مستهدفة

# تدريب النموذج
regressor = LinearRegressor(num_features=X.shape[1])  # تحديد عدد الخصائص
error_history = regressor.fit(X, y, learning_rate=0.01, epochs=100)

# رسم الرسم البياني بعد التدريب
epochs = range(1, len(error_history) + 1)
plt.plot(epochs, error_history, 'b', label='MSE')
plt.title('График обучения')
plt.xlabel('Эпохи')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### Классификатор
# #### Context
# When a bank receives a loan application, based on the applicant’s profile the bank has to make a decision regarding whether to go ahead with the loan approval or not. Two types of risks are associated with the bank’s decision."
#
# "If the applicant is a good credit risk, i.e. is likely to repay the loan, then not approving the loan to the person results in a loss of business to the bank
# If the applicant is a bad credit risk, i.e. is not likely to repay the loan, then approving the loan to the person results in a financial loss to the bank."
#
# The predictors that may potentially have any influence on Creditability:
#
# Account Balance: No account (1), None (No balance) (2), Some Balance (3)
#
# Payment Status: Some Problems (1), Paid Up (2), No Problems (in this bank) (3)
#
# Savings/Stock Value: None, Below 100 DM, [100, 1000] DM, Above 1000 DM
#
# Employment Length: Below 1 year (including unemployed), [1, 4), [4, 7), Above 7
#
# Sex/Marital Status: Male Divorced/Single, Male Married/Widowed, Female
#
# No of Credits at this bank: 1, More than 1
#
# Guarantor: None, Yes
#
# Concurrent Credits: Other Banks or Dept Stores, None
#
# ForeignWorker variable may be dropped from the study
#
# Purpose of Credit: New car, Used car, Home Related, Other

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# تحميل البيانات
data = pd.read_csv('C:/Users/Tech/Downloads/german.csv', sep=';')

# عرض أول 5 أسطر من البيانات
print(data.head())

# تحديد المتغيرات
Y = data['Creditability']  # المتغير المستهدف
X = data.drop('Creditability', axis=1)  # المتغيرات المستقلة

# تحويل الأعمدة الفئوية إلى قيم عددية باستخدام LabelEncoder
categorical_columns = X.select_dtypes(include=['object']).columns  # الأعمدة الفئوية
encoder = LabelEncoder()

for column in categorical_columns:
    X[column] = encoder.fit_transform(X[column])

# تحجيم البيانات باستخدام StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# تقسيم البيانات إلى تدريب واختبار
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# عرض أول 5 أسطر بعد التحجيم
print(X_train[:5])
# Out:
#    Creditability  Account_Balance  Duration_of_Credit_monthly  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment_Status_of_Previous_Credit  Purpose  Credit_Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value_Savings_Stocks  Length_of_current_employment  Instalment_per_cent  \
# 0                     1                             2                    4
# ...

# %%
print(data.describe())
# Out:
#        Creditability  Account_Balance  Duration_of_Credit_monthly  \
# count    1000.000000      1000.000000                 1000.000000
# mean        0.700000         2.577000                   20.903000
# std         0.458487         1.257638                   12.058814
# min         0.000000         1.000000                    4.000000
# 25%         0.000000         1.000000                   12.000000
# 50%         1.000000         2.000000                   18.000000
# 75%         1.000000         4.000000                   24.000000
# max         1.000000         4.000000                   72.000000
#
#        Payment_Status_of_Previous_Credit      Purpose  Credit_Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# min                              0.00000     0.000000      250.00000
# ...

# %%
# Вычисляем среднее по столбцам
mean = X.mean(axis=0)

# Вычисляем стандартное отклонение по столбцам
std = X.std(axis=0)

# Нормализуем данные по столбцам (стандартное масштабирование)
normalized_X = (X - mean) / std

# %%
class LinearClassifier(LinearModel):
    def fit(self, X, y, learning_rate=0.01, epochs=100):
        error_history = []  # لحفظ قيم الخسارة (BCE)
        for _ in range(epochs):
            predictions = self(X)  # التنبؤات
            sigmoid = 1 / (1 + np.exp(-predictions))  # دالة السيغمويد
            epsilon = 1e-15  # لتجنب القيم المتطرفة
            sigmoid = np.clip(sigmoid, epsilon, 1 - epsilon)  # تحديد قيم sigmoid
            error = y - sigmoid  # حساب الخطأ
            gradient = -np.dot(X.T, error) / len(X)  # حساب التدرج
            self.weights -= learning_rate * gradient  # تحديث الأوزان
            self.bias -= learning_rate * np.mean(error)  # تحديث الانحياز
            current_error = -np.mean(y * np.log(sigmoid) + (1 - y) * np.log(1 - sigmoid))  # حساب خسارة BCE
            error_history.append(current_error)  # إضافة قيمة الخسارة إلى history
        return error_history

# %%
epochs = range(1, len(error_history) + 1)
plt.plot(epochs, error_history, 'b', label='BCE')
plt.title('График обучения')
plt.xlabel('Эпохи')
plt.ylabel('BCE')
plt.legend()
plt.show()

# %%
# Проверка количества столбцов в normalized_X
print(f"Количество столбцов в normalized_X: {normalized_X.shape[1]}")

# Проверка количества весов в модели
print(f"Количество весов в модели: {lc.num_features}")

# Убедитесь, что normalized_X содержит такое же количество столбцов, как и веса
if normalized_X.shape[1] != lc.num_features:
    # Используйте только первые столбцы, чтобы соответствовать количеству весов
    normalized_X = normalized_X.iloc[:, :lc.num_features]  # Используем iloc для выбора столбцов по индексу
    print("normalized_X был изменен, чтобы содержать соответствующие столбцы.")

# Проверка предсказаний
pred = lc.predict(normalized_X)

# Расчет точности
accuracy = (pred == Y).sum() / len(Y)
print('Точность: ', accuracy)
# Out:
# Количество столбцов в normalized_X: 20
# Количество весов в модели: 5
# normalized_X был изменен, чтобы содержать соответствующие столбцы.
# Точность:  0.303
# C:\Users\Tech\AppData\Local\Temp\ipykernel_15040\3946720644.py:50: RuntimeWarning: overflow encountered in exp
#   sigmoid = 1 / (1 + np.exp(-predictions))

# %% [markdown]
# Вычислите для этой модели ROC-AUC, precision, recall и f1
